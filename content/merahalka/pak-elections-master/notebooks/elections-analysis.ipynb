# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Pakistan_Election_Results_1970_2013_Cleaned.csv')
# Out:
# /Users/zohaib/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (0,7,9,16,22,23,24,27,31,36,38,44,49,56,58,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#   id_no   NA  NA1           NAName sr             CandidateName Party party1  \
# 0  5201  1.0  1.0  NA-1 PESHAWAR-I  1        Haji Dost Mohammad   IND    138
# 1  5202  NaN  1.0  NA-1 PESHAWAR-I  2  Haji Ghulam Ahmad Bilour   ANP      5
# 2  5203  NaN  1.0  NA-1 PESHAWAR-I  3             Mr.Rifatullah   IND     39
# 3  5204  NaN  1.0  NA-1 PESHAWAR-I  4    Syed Javed Hassan shah   IND     39
# 4  5205  NaN  1.0  NA-1 PESHAWAR-I  5       Syed Zafar Ali Shah   PPP    124
#
#   party_93 nnparty ...  Winner ndivision nZones_20 nRegions_12 Nregions_11  \
# 0      102      75 ...
# 1        5       9 ...
# 2       39      88 ...
# 3       39      88 ...
# 4      124       1 ...
#
#   nprov party_2013 ID_Respondent n_Registerd  ap1
# 0                            1.0         3.0  1.0
# 1                            2.0         3.0  1.0
# 2                            3.0         3.0  1.0
# 3                            4.0         3.0  1.0
# 4                            5.0         3.0  1.0
#
# ...

# %%
df.CandidateName.describe()
# Out:
# count          16022
# unique         14173
# top       Imran Khan
# freq              12
# Name: CandidateName, dtype: object

# %%
df[['NA1','CandidateName','Party','Votes','Winner','Year']].head(10)
# Out:
#    NA1                 CandidateName Party  Votes Winner    Year
# 0  1.0            Haji Dost Mohammad   IND   9725         1993.0
# 1  1.0      Haji Ghulam Ahmad Bilour   ANP  35755         1993.0
# 2  1.0                 Mr.Rifatullah   IND    360         1993.0
# 3  1.0        Syed Javed Hassan shah   IND    408         1993.0
# 4  1.0           Syed Zafar Ali Shah   PPP  40343         1993.0
# 5  1.0               Mr. Zahoor Khan   IND    834         1993.0
# 6  1.0             Mr. Ghulam Jaafar   IND   1943         1993.0
# 7  1.0            Mr. Mohammad Rafiq   IND    447         1993.0
# 8  1.0             Mrs. Zakira Zslam   HPG     91         1993.0
# 9  2.0  Arbab Muhammad Jehangir Khan   PPP  27345         1993.0

# %%
df.groupby('Year')['Winner'].head()
# Out:
# 0
# 1
# 2
# 3
# 4
# 1434
# 1435
# 1436
# 1437
# 1438
# 3195
# 3196
# 3197
# 3198
# 3199
# 5261
# 5262
# 5263
# 5264
# 5265
# 6664     NaN
# 7432
# 7433
# 7434
# 7435
# 7436
# 8748
# 8749
# 8750
# 8751
# 8752
# 10040
# 10041
# 10042
# 10043
# 10044
# 10770
# 10771
# 10772
# 10773
# 10774
# 11567
# 11568
# 11569
# 11570
# 11571
# Name: Winner, dtype: object

# %%
df[df.CandidateName == 'Imran Khan'].ix[:,2:22]
# Out:
#          NA1                                             NAName sr  \
# 1508    11.0  NA-11 Abbotabad - Cum - Haripur - I (Old Abbot...  6
# 1541    18.0     NA-18 D.I. Khan - Cum - Kulachi (Old D.I.Khan)  4
# 1572    21.0                                    NA-21 Sawat - I  3
# 1909    35.0                              NA-35 Federal Capital  3
# 2005    53.0                                 NA-53 Mianwali - I  5
# 2277    94.0                                   NA-94 Lahore-III  5
# 2288    95.0                                    NA-95 Lahore-IV  7
# 3018   190.0                            NA-190 Karachi South-II  6
# 5414    22.0                                   ?NA-22 Battagram  3
# 11916   26.0                                      NA-26 (BANNU)
# 12326   46.0                             NA-46 (TRIBAL AREA-XI)
# 12545   56.0                             NA-56 (RAWALPINDI-VII)
#
#       CandidateName                            Party party1 party_93 nnparty  \
# ...
